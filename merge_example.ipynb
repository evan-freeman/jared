# %% [markdown]
# # Example of merging dfs

# %%
import pandas as pd
import numpy as np
import sqlite3

# %%
# Sample df

patient_df = pd.DataFrame({
    'PatientID' : range(1, 51),
    'BloodPressure': np.random.randint(80, 180, 50),
    'Smoking': np.random.randint(0, 2, 50)
    # 'WhiteBloodCellCount': np.random.randint(300, 800, 50),
    # 'CholesterolLevels': np.random.randint(5, 30, 50)
})

BloodPressure_range_df = pd.DataFrame({
    'BloodPressureDiagnosisID': range(3),
    'Low': [0, 121, 141],
    'High': [120, 140, 5000]
})

BloodPressureDiagnosis_df = pd.DataFrame({
    'BloodPressureDiagnosisID': range(3),
    'BloodPressureDiagnosis': ['No treatment needed', 'Exercise Daily', 'You\'re screwed!']
})

SmokingDiagnosis_df = pd.DataFrame({
    'Smoking': [0, 1],
    'SmokingDiagnosis': ['Good job!', 'STOP IT NOW DUMMY!']
})

# %%
patient_df
# Out:
#     PatientID  BloodPressure  Smoking
# 0           1            168        1
# 1           2             91        0
# 2           3            125        1
# 3           4            142        1
# 4           5            165        1
# 5           6            133        1
# 6           7             92        0
# 7           8            145        1
# 8           9            105        1
# 9          10            112        0
# 10         11            137        1
# 11         12             83        0
# 12         13            127        0
# 13         14             90        1
# 14         15            168        1
# 15         16            178        1
# 16         17            164        0
# 17         18            147        0
# 18         19            157        1
# 19         20             90        1
# 20         21            127        1
# 21         22            157        1
# 22         23            140        1
# 23         24             81        1
# 24         25            104        1
# 25         26            151        0
# 26         27            155        1
# 27         28            117        0
# 28         29            121        1
# 29         30            144        0
# 30         31            111        1
# 31         32            163        0
# 32         33            124        0
# 33         34            173        0
# 34         35            104        0
# 35         36            105        1
# 36         37            150        0
# 37         38            119        0
# 38         39            166        1
# 39         40            173        0
# 40         41            115        0
# 41         42            158        1
# 42         43            145        1
# 43         44            121        0
# 44         45            104        0
# 45         46            155        0
# 46         47             81        0
# 47         48            174        1
# 48         49             98        0
# 49         50             96        1

# %%
BloodPressure_range_df
# Out:
#    BloodPressureDiagnosisID  Low  High
# 0                         0    0   120
# 1                         1  121   140
# 2                         2  141  5000

# %%
BloodPressureDiagnosis_df
# Out:
#    BloodPressureDiagnosisID BloodPressureDiagnosis
# 0                         0    No treatment needed
# 1                         1         Exercise Daily
# 2                         2        You're screwed!

# %%
SmokingDiagnosis_df
# Out:
#    Smoking    SmokingDiagnosis
# 0        0           Good job!
# 1        1  STOP IT NOW DUMMY!

# %%
# There's no good way in pandas to join on a range of values, so easiest to use sql for any part involving a range. The rest can be done easily with merges.

conn = sqlite3.connect(':memory:')
patient_df.to_sql("patient_df", conn, index=False)
BloodPressure_range_df.to_sql("BloodPressure_range_df", conn, index=False)
query = "SELECT * FROM patient_df LEFT JOIN BloodPressure_range_df ON patient_df.BloodPressure BETWEEN BloodPressure_range_df.Low AND BloodPressure_range_df.High"
new_patient_df = pd.read_sql_query(query, conn)

new_patient_df
# Out:
#     PatientID  BloodPressure  Smoking  BloodPressureDiagnosisID  Low  High
# 0           1            168        1                         2  141  5000
# 1           2             91        0                         0    0   120
# 2           3            125        1                         1  121   140
# 3           4            142        1                         2  141  5000
# 4           5            165        1                         2  141  5000
# 5           6            133        1                         1  121   140
# 6           7             92        0                         0    0   120
# 7           8            145        1                         2  141  5000
# 8           9            105        1                         0    0   120
# 9          10            112        0                         0    0   120
# 10         11            137        1                         1  121   140
# 11         12             83        0                         0    0   120
# 12         13            127        0                         1  121   140
# 13         14             90        1                         0    0   120
# 14         15            168        1                         2  141  5000
# 15         16            178        1                         2  141  5000
# 16         17            164        0                         2  141  5000
# 17         18            147        0                         2  141  5000
# 18         19            157        1                         2  141  5000
# 19         20             90        1                         0    0   120
# 20         21            127        1                         1  121   140
# 21         22            157        1                         2  141  5000
# 22         23            140        1                         1  121   140
# 23         24             81        1                         0    0   120
# 24         25            104        1                         0    0   120
# 25         26            151        0                         2  141  5000
# 26         27            155        1                         2  141  5000
# 27         28            117        0                         0    0   120
# 28         29            121        1                         1  121   140
# 29         30            144        0                         2  141  5000
# 30         31            111        1                         0    0   120
# 31         32            163        0                         2  141  5000
# 32         33            124        0                         1  121   140
# 33         34            173        0                         2  141  5000
# 34         35            104        0                         0    0   120
# 35         36            105        1                         0    0   120
# 36         37            150        0                         2  141  5000
# 37         38            119        0                         0    0   120
# 38         39            166        1                         2  141  5000
# 39         40            173        0                         2  141  5000
# 40         41            115        0                         0    0   120
# 41         42            158        1                         2  141  5000
# 42         43            145        1                         2  141  5000
# 43         44            121        0                         1  121   140
# 44         45            104        0                         0    0   120
# 45         46            155        0                         2  141  5000
# 46         47             81        0                         0    0   120
# 47         48            174        1                         2  141  5000
# 48         49             98        0                         0    0   120
# 49         50             96        1                         0    0   120

# %%
new_patient_df.merge(BloodPressureDiagnosis_df).merge(SmokingDiagnosis_df).sort_values('PatientID')
# Out:
#     PatientID  BloodPressure  Smoking  BloodPressureDiagnosisID  Low  High  \
# 0           1            168        1                         2  141  5000
# 36          2             91        0                         0    0   120
# 21          3            125        1                         1  121   140
# 1           4            142        1                         2  141  5000
# 2           5            165        1                         2  141  5000
# 22          6            133        1                         1  121   140
# 37          7             92        0                         0    0   120
# 3           8            145        1                         2  141  5000
# 13          9            105        1                         0    0   120
# 38         10            112        0                         0    0   120
# 23         11            137        1                         1  121   140
# 39         12             83        0                         0    0   120
# 47         13            127        0                         1  121   140
# 14         14             90        1                         0    0   120
# 4          15            168        1                         2  141  5000
# 5          16            178        1                         2  141  5000
# 27         17            164        0                         2  141  5000
# 28         18            147        0                         2  141  5000
# 6          19            157        1                         2  141  5000
# 15         20             90        1                         0    0   120
# 24         21            127        1                         1  121   140
# 7          22            157        1                         2  141  5000
# 25         23            140        1                         1  121   140
# 16         24             81        1                         0    0   120
# 17         25            104        1                         0    0   120
# 29         26            151        0                         2  141  5000
# 8          27            155        1                         2  141  5000
# 40         28            117        0                         0    0   120
# 26         29            121        1                         1  121   140
# 30         30            144        0                         2  141  5000
# 18         31            111        1                         0    0   120
# 31         32            163        0                         2  141  5000
# 48         33            124        0                         1  121   140
# 32         34            173        0                         2  141  5000
# 41         35            104        0                         0    0   120
# 19         36            105        1                         0    0   120
# 33         37            150        0                         2  141  5000
# 42         38            119        0                         0    0   120
# 9          39            166        1                         2  141  5000
# 34         40            173        0                         2  141  5000
# 43         41            115        0                         0    0   120
# 10         42            158        1                         2  141  5000
# 11         43            145        1                         2  141  5000
# 49         44            121        0                         1  121   140
# 44         45            104        0                         0    0   120
# 35         46            155        0                         2  141  5000
# 45         47             81        0                         0    0   120
# 12         48            174        1                         2  141  5000
# 46         49             98        0                         0    0   120
# 20         50             96        1                         0    0   120
#
#    BloodPressureDiagnosis    SmokingDiagnosis
# 0         You're screwed!  STOP IT NOW DUMMY!
# 36    No treatment needed           Good job!
# 21         Exercise Daily  STOP IT NOW DUMMY!
# 1         You're screwed!  STOP IT NOW DUMMY!
# 2         You're screwed!  STOP IT NOW DUMMY!
# 22         Exercise Daily  STOP IT NOW DUMMY!
# 37    No treatment needed           Good job!
# 3         You're screwed!  STOP IT NOW DUMMY!
# 13    No treatment needed  STOP IT NOW DUMMY!
# 38    No treatment needed           Good job!
# 23         Exercise Daily  STOP IT NOW DUMMY!
# 39    No treatment needed           Good job!
# 47         Exercise Daily           Good job!
# 14    No treatment needed  STOP IT NOW DUMMY!
# 4         You're screwed!  STOP IT NOW DUMMY!
# 5         You're screwed!  STOP IT NOW DUMMY!
# 27        You're screwed!           Good job!
# 28        You're screwed!           Good job!
# 6         You're screwed!  STOP IT NOW DUMMY!
# 15    No treatment needed  STOP IT NOW DUMMY!
# 24         Exercise Daily  STOP IT NOW DUMMY!
# 7         You're screwed!  STOP IT NOW DUMMY!
# 25         Exercise Daily  STOP IT NOW DUMMY!
# 16    No treatment needed  STOP IT NOW DUMMY!
# 17    No treatment needed  STOP IT NOW DUMMY!
# 29        You're screwed!           Good job!
# 8         You're screwed!  STOP IT NOW DUMMY!
# 40    No treatment needed           Good job!
# 26         Exercise Daily  STOP IT NOW DUMMY!
# 30        You're screwed!           Good job!
# 18    No treatment needed  STOP IT NOW DUMMY!
# 31        You're screwed!           Good job!
# 48         Exercise Daily           Good job!
# 32        You're screwed!           Good job!
# 41    No treatment needed           Good job!
# 19    No treatment needed  STOP IT NOW DUMMY!
# 33        You're screwed!           Good job!
# 42    No treatment needed           Good job!
# 9         You're screwed!  STOP IT NOW DUMMY!
# 34        You're screwed!           Good job!
# 43    No treatment needed           Good job!
# 10        You're screwed!  STOP IT NOW DUMMY!
# 11        You're screwed!  STOP IT NOW DUMMY!
# 49         Exercise Daily           Good job!
# 44    No treatment needed           Good job!
# 35        You're screwed!           Good job!
# 45    No treatment needed           Good job!
# 12        You're screwed!  STOP IT NOW DUMMY!
# 46    No treatment needed           Good job!
# 20    No treatment needed  STOP IT NOW DUMMY!
